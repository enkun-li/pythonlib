# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
cov = np.loadtxt('SL_cov.txt', unpack=True)

# %%
dim = int(np.sqrt(cov.shape[1]))
cll = np.reshape(cov[0],(dim,dim))
cls = np.reshape(cov[1],(dim,dim))
css = np.reshape(cov[3],(dim,dim))

# %%
im = plt.imshow(cll)
plt.colorbar(im)

# %%
im = plt.imshow(cls)
plt.colorbar(im)

# %%
im = plt.imshow(css)
plt.colorbar(im)
